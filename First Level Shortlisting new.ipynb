# %% [markdown]
# # Fist Level of Shortlisting

# %%
# Ensure you have installed cloudant 
# !pip install cloudant
import json

# %%
# @hidden_cell
# The following code contains the credentials for a connection in your Project.
# You might want to remove those credentials before you share your notebook.
credentials_1 = {
    'username': 'a782bb37-dcf6-428a-82df-f57fb6674427-bluemix',
    'password': """f6eca12652e457e6d66f402304a3425e644e55f226ce74fe93bc38c83c061ae2""",
    'custom_url': 'https://a782bb37-dcf6-428a-82df-f57fb6674427-bluemix:f6eca12652e457e6d66f402304a3425e644e55f226ce74fe93bc38c83c061ae2@a782bb37-dcf6-428a-82df-f57fb6674427-bluemix.cloudantnosqldb.appdomain.cloud',
    'port': '50000',
    'connectionPath': '/applicants/undefined',
}

# %%
# Logon using the credentials with the url
from cloudant import Cloudant
u =  credentials_1["username"]
p =  credentials_1["password"]
url =  credentials_1["custom_url"]
client = Cloudant(u, p, url=url, connect=True, auto_renew=True)

# %%
# cloudant database name
db = client['trial']

# %%
response = db.all_docs(limit=500, include_docs= True,)

# %%
# put document bodies into an array
docs = []
for r in response['rows']:
    docs.append(r['doc'])
print(docs)
# Out:
# [{'_id': 'abhi@abc.com', '_rev': '1-43303f538a0c214a94e4ae85733c675e', 'email': 'abhi@abc.com', 'experience': 1, 'total_per_PG': 80, 'total_per_G': 76, 'total_per_12': 87, 'total_per_10': 95, 'analytic_tools': [{'tableau': False, 'powerbi': True, 'msexcel': False, 'plotly': False, 'dash': False}], 'languages': [{'python': False, 'r': True, 'julia': False, 'java': False, 'scala': False}], 'BDA_tools': [{'hadoop': True, 'spark': False, 'storm': False, 'ceph': False, 'hydra': False}], 'SQL_DB': [{'mysql': True, 'mssqlserver': False, 'postgresql': True, 'oracle': False, 'couchdb': False}], 'NO_SQL_DB': [{'mongodb': True, 'redis': False, 'casandra': True}]}, {'_id': 'aru@xyz.com', '_rev': '1-735fb04decebf6a317a059a08052ab86', 'email': 'aru@xyz.com', 'experience': 2, 'total_per_PG': 83, 'total_per_G': 79, 'total_per_12': 91, 'total_per_10': 89, 'analytic_tools': [{'tableau': True, 'powerbi': True, 'msexcel': '', 'plotly': '', 'dash': ''}], 'languages': [{'python': True, 'r': True, 'julia':
# ...

# %%
docs[4]
# Out:
# {'_id': 'dnyanu@lmn.com',
#  '_rev': '3-f701fc599cc587faa1cbfe842b9a7635',
#  'email': 'dnyanu@lmn.com',
#  'experience': 1,
#  'total_per_PG': 89,
#  'total_per_G': 78,
#  'total_per_12': 88,
#  'total_per_10': 90,
#  'analytic_tools': [{'tableau': '',
#    'powerbi': True,
#    'msexcel': '',
#    'plotly': '',
#    'dash': ''}],
#  'languages': [{'python': True,
#    'r': '',
#    'julia': '',
#    'java': '',
#    'scala': ''}],
#  'BDA_tools': [{'hadoop': True,
#    'spark': '',
#    'storm': '',
#    'ceph': '',
#    'hydra': ''}],
#  'SQL_DB': [{'mysql': True,
#    'mssqlserver': '',
#    'postgresql': '',
#    'oracle': '',
#    'couchdb': ''}],
#  'NO_SQL_DB': [{'mongodb': True, 'redis': '', 'casandra': ''}]}

# %%
pass_list=[]
for i in range(len(docs)):
    d=docs[i]
    if d.get('analytic_tools')!=None and d.get('languages')!=None and d.get('experience')!=None and d.get('BDA_tools')!=None and d.get('SQL_DB')!=None and d.get('NO_SQL_DB')!=None and d.get('total_per_PG')!=None and d.get('total_per_G')!=None and d.get('total_per_12')!=None and d.get('total_per_10')!=None:
        analytic=d.get('analytic_tools')[0].get('tableau') == True or d.get('analytic_tools')[0].get('powerbi') == True or d.get('analytic_tools')[0].get('msexcel') == True or d.get('analytic_tools')[0].get('plotly') == True or d.get('analytic_tools')[0].get('dash') == True
        language= d.get('languages')[0]['python']==True or d.get('languages')[0]['r']==True or d.get('languages')[0]['julia']==True or d.get('languages')[0]['java']==True or d.get('languages')[0]['scala']==True
        bda = d.get('BDA_tools')[0].get('hadoop')==True or d.get('BDA_tools')[0].get('spark')==True or d.get('BDA_tools')[0].get('storm')==True or d.get('BDA_tools')[0].get('ceph')==True or d.get('BDA_tools')[0].get('hydra')==True
        sql=  d.get('SQL_DB')[0]['mysql']==True or d.get('SQL_DB')[0]['mssqlserver']==True or d.get('SQL_DB')[0]['postgresql']==True or d.get('SQL_DB')[0]['oracle']==True or d.get('SQL_DB')[0]['couchdb']==True
        nosql= d.get('NO_SQL_DB')[0]['mongodb']==True or d.get('NO_SQL_DB')[0]['casandra']==True or d.get('NO_SQL_DB')[0]['redis']==True
        if analytic and language and bda and sql and nosql and d.get('experience')>1 and d.get('total_per_PG')>65 and d.get('total_per_G')>65 and d.get('total_per_12')>65 and d.get('total_per_10')>65 :
            print(d)
            pass_list.append(d['email'])
            print(i)
print(pass_list)
# Out:
# {'_id': 'aru@xyz.com', '_rev': '1-735fb04decebf6a317a059a08052ab86', 'email': 'aru@xyz.com', 'experience': 2, 'total_per_PG': 83, 'total_per_G': 79, 'total_per_12': 91, 'total_per_10': 89, 'analytic_tools': [{'tableau': True, 'powerbi': True, 'msexcel': '', 'plotly': '', 'dash': ''}], 'languages': [{'python': True, 'r': True, 'julia': '', 'java': '', 'scala': ''}], 'BDA_tools': [{'hadoop': True, 'spark': True, 'storm': '', 'ceph': '', 'hydra': ''}], 'SQL_DB': [{'mysql': '', 'mssqlserver': True, 'postgresql': '', 'oracle': True, 'couchdb': ''}], 'NO_SQL_DB': [{'mongodb': True, 'redis': '', 'casandra': True}]}
# 1
# ...
